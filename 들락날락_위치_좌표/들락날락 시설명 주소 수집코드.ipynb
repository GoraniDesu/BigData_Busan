# %% [markdown]
# # 들락날락 사이트에서 들락날락 시설명과 주소 가져오기
# ## 1. 들락날락 사이트에서 '우리동네 들락날락' -> '들락날락 정보'에 접속
# - ### https://busan.go.kr/bschild/dnol/list.nm?menuCd=8&lang=ko&url=dnol
# ## 2. '들락날락 정보'에서 확인할 수 있는 106개의 들락날락 시설 중 하나를 클릭하여 각 들락날락 정보의 시설명과 주소가 해당하는 HTML 테그 찾기
# - ### 예시로 반여도서관 들락날락을 클릭하고 f12를 눌러 개발자 도구를 열고 Ctrl+Shift+C를 눌러 원하는 데이터에 마우스를 대면 그 데이터가 해당하는 HTML 테그를 찾을 수 있습니다.
#     - https://busan.go.kr/bschild/dnol/view.nm?menuCd=8&lang=ko&url=dnol&olSkey=DNOL0000000000086
#     - '반여도서관 들락날락'의 HTML 테그는 <div class="con_title">반여도서관 들락날락</div>입니다.
#     - 주소의 '해운대구 재반로282번길 38(반여동)'의 HTML 테그는 <td data-th="주소">해운대구 재반로282번길 38(반여동)</td>입니다.
#     - 따라서 들락날락 시설명은 <div class="con_title"> 테그와 </div> 테그 사이의 문자열에 해당하고 들락날락의 주소는 <td data-th="주소"> 테그와 </td> 테그 사이의 문자열에 해당합니다.
# ## 3. 각각의 들락날락 정보의 URL 차이점 분석
# - ### 사상구육아종합지원센터 들락날락
#     - https://busan.go.kr/bschild/dnol/view.nm?menuCd=8&lang=ko&url=dnol&olSkey=DNOL0000000000064
# - ### 국립해양박물관내 어린이해양도서관 들락날락(조성중)
#     - https://busan.go.kr/bschild/dnol/view.nm?menuCd=8&lang=ko&url=dnol&olSkey=DNOL0000000000230
# - ### URL의 차이점을 분석한 결과 차이가 있음을 확인
#     - 'https://busan.go.kr/bschild/dnol/view.nm?menuCd=8&lang=ko&url=dnol&olSkey=DNOL0000000000'까지는 모두 같은 반면 맨 뒤에 숫자 3개가 다릅니다. 이 URL 뒤에 064를 붙이면 사상구육아종합지원센터 들락날락을, 230을 붙이면 국립해양박물관내 어린이해양도서관 들락날락(조성중)을 보여줍니다.
# ## 4. 이 차이점을 이용하여 들락날락 사이트에서 106개의 들락날락의 시설명과 주소를 한 번에 가져오는 코드 구상
# - ### URL 맨 뒷자리 숫자 검색 범위는 0부터 300까지로 정했습니다.
#     - ### 이유는 총 106개소의 들락날락이 있는데 각 들락날락 시설별로 URL을 0부터 105까지 혹은 1부터 106까지 설정했을 것이라는 예상과 달리 000, 001로 입력하면 404 에러가 뜨고 230 같이 106 이상의 숫자를 확인했기 때문입니다.
#     - ### 그래서 106개소의 들락날락이 모두 포함될 것으로 예상되면서 과도한 접속으로 사이트에 부담을 주지 않는 범위로 0부터 300까지 설정하였습니다.

# %%
# %pip install requests
# %pip install bs4
# %pip install pandas
# 위 라이브러리들을 먼저 설치

# %%
import requests
from bs4 import BeautifulSoup
# requests 라이브러리를 이용해서 웹 페이지를 가져오고 BeautifulSoup 라이브러리를 이용해서 HTML을 파싱하는 작업을 진행
import pandas as pd
# 수집한 데이터를 DataFrame 형태로 변환하기 위해 pandas 라이브러리 활용
import time
import random
# 과도한 요청으로 들락날락 서버에 부담을 주지 않기 위해
# 일정 시간 동안 쉬었다가 다시 URL에 접속할 수 있도록 time과 random 라이브러리 활용

data = []

for i in range(0, 301):
    response = requests.get(f'https://busan.go.kr/bschild/dnol/view.nm?menuCd=8&lang=ko&url=dnol&olSkey=DNOL0000000000{i:03d}')
    # requests.get() 메소드를 이용해서 웹 페이지를 가져오고
    # response 변수에 요청한 웹 페이지의 응답을 저장
    # response 변수에는 요청한 웹 페이지의 HTML 코드와 상태 코드가 포함되어 있다.
    # 이때 상태 코드는 요청이 성공했는지 실패했는지를 나타내는 코드이다.
    
    time.sleep(random.uniform(3, 5))
    # 3~5초 동안 쉬었다가 다시 요청하도록 설정
    
    if response.status_code != 200:
        print(f"olSkey=DNOL0000000000{i:03d}: 요청 실패 - {response.status_code}")
        continue
    # 만약 HTTP 응답 상태 코드가 200(정상)이 아니라면,
    # 해당 페이지의 데이터 수집을 건너뛰고(continue)
    # 실패한 olSkey와 상태 코드를 출력하여 어떤 요청이 실패했는지 확인할 수 있도록 함
    
    else:
        # HTTP 응답 상태 코드가 200(정상)일 때 실행
        soup = BeautifulSoup(response.text, 'html.parser')
        # BeautifulSoup 객체를 생성
        # response.text를 이용해서 HTML 코드를 가져오고 
        # 'html.parser'를 이용해서 HTML 코드를 파싱 -> soup 변수에 파싱된 HTML 코드가 저장됨

        이름 = soup.select_one('.con_title') # 시설명 추출
        주소 = soup.select_one('td[data-th="주소"]') # 주소 추출
        이름 = 이름.text # 태그에서 텍스트만 추출
        주소 = 주소.text # 태그에서 텍스트만 추출
        data.append([f'{i:03d}', 이름, 주소]) # 결과 리스트에 추가
        print(f"olSkey=DNOL0000000000{i:03d}: 이름: {이름}, 주소: {주소}") # 결과 출력

df = pd.DataFrame(data, columns=['주소번호', '이름', '주소']) # 수집한 데이터를 DataFrame으로 변환
df.to_csv('부산광역시 들락날락 주소 모음.csv') # DataFrame을 CSV 파일로 저장
busan_df = pd.read_csv('부산광역시 들락날락 주소 모음.csv') # 저장한 CSV 파일을 다시 읽어옴

len(busan_df.index)
# DataFrame의 행 개수(수집한 들락날락 데이터 개수)를 출력
# 총 106개소의 들락날락으로 106이 출력되어야 하나 107이 출력됨을 확인

# %%
pd.set_option('display.max_rows', None)  # DataFrame 출력 시 모든 행을 화면에 표시하도록 설정
busan_df # 수집된 데이터를 출력하여 중복되는 데이터 검토

# %% [markdown]
# 솔바람문화센터 들락날락 중복 확인
# - 솔바람문화센터 들락날락,  부산 사하구 하단동 786-1번지 일원
#     - "솔바람"으로 검색해도 안 나옴. URL로만 확인 가능.
# - 솔바람문화센터 들락날락(조성중),  부산광역시 사하구 에덴공원 내 솔바람문화센터
#     - URL 맨 뒷자리 숫자가 218, 219로 1밖에 차이가 나지 않는 것으로 보아 솔바람문화센터 들락날락 정보를 수정하고 수정되지 않은 URL은 삭제하지 않은 것으로 추정.

# %%
busan_df1 = pd.read_csv('부산광역시 들락날락 주소 모음.csv')
busan_df1.drop([91], inplace=True)
# 솔바람문화센터 들락날락,  부산 사하구 하단동 786-1번지 일원에 해당하는 행 삭제
busan_df1.drop('Unnamed: 0', axis=1, inplace=True) # 'unnamed: 0' 열 삭제
busan_df1.to_csv('부산광역시 들락날락 주소 모음.csv', index=False) # 인덱스 없이 저장

# %% [markdown]
# # 수집한 들락날락 주소를 좌표로 변환하기
# ## 주소를 좌표로 변환하는 오픈API 이용
# ### 브이월드의 Geocoder API 2.0 레퍼런스 활용
# - https://www.vworld.kr/dev/v4dv_geocoderguide2_s001.do

# %%
import pandas as pd
import requests
import time
import random

busan_df2 = pd.read_csv('부산광역시 들락날락 주소 모음.csv')
busan_df2['위도'] = pd.NA
busan_df2['경도'] = pd.NA
# 위도, 경도 컬럼을 추가하고 모두 NaN 값으로 채움

for idx, addr in enumerate(busan_df2['주소']):
    apiurl = 'https://api.vworld.kr/req/address?'
    params = {
        "service": "address",
        "request": "getcoord",
        "crs": "epsg:4326",
        "address": addr,
        "format": "json",
        "type": "road", # 도로명 주소로 좌표 변환 시도
        "key": '', # 발급받은 API 키를 작은따옴표 사이에 입력
    }
    response = requests.get(apiurl, params=params, timeout=2)
    time.sleep(random.uniform(1, 2))  # 1~2초 대기(과도한 요청으로 인한 서버 부담 방지)
    if response.status_code == 200:
        response_json = response.json()
        if 'response' in response_json and 'result' in response_json['response'] and 'point' in response_json['response']['result']:
            point = response_json['response']['result']['point']
            # 정상 응답이면서 좌표(point) 정보가 있으면 아래 코드 실행

            busan_df2.at[idx, '위도'] = point['y']
            busan_df2.at[idx, '경도'] = point['x']
            # busan_df2 변수의 위도/경도 컬럼에 위도/경도 저장
            
            print(f"인덱스 {idx}, 주소 '{addr}' 출력 성공: 위도 {point['y']}, 경도 {point['x']}")
            # 위도/경도 출력 및 저장이 성공했음을 알기 쉽도록 메시지 출력
        
        else:
            # 도로명 주소로 실패 시 지번 주소로 재시도
            print(f"인덱스 {idx}, 주소 '{addr}' 출력 실패. 재시도")
            params['type'] = 'parcel'
            response = requests.get(apiurl, params=params, timeout=2)
            time.sleep(random.uniform(1, 2))
            if response.status_code == 200:
                response_json = response.json()
                if 'response' in response_json and 'result' in response_json['response'] and 'point' in response_json['response']['result']:
                    point = response_json['response']['result']['point']
                    busan_df2.at[idx, '위도'] = point['y']
                    busan_df2.at[idx, '경도'] = point['x']
                    print(f"인덱스 {idx}, 주소 '{addr}' 재시도 성공: 위도 {point['y']}, 경도 {point['x']}")
                else:
                    # 도로명/지번 주소 모두 실패하면 아래 메시지 출력
                    print(f"인덱스 {idx}, 주소 '{addr}' 출력 실패")

            else: # API 요청 자체가 실패한 경우 아래 메시지 출력
                print(f"인덱스 {idx}, 주소 '{addr}' 재시도 요청 실패: 상태 코드 {response.status_code}")
    else:
        print(f"인덱스 {idx}, 주소 '{addr}' 요청 실패: 상태 코드 {response.status_code}")

busan_df2.to_csv('부산광역시_좌표추가.csv', index=False, encoding='utf-8')
# 위도/경도를 추가한 데이터를 다른 CSV 파일로 저장
# Out:
# 인덱스 0, 주소 '부산시 사하구 다대낙조2길 9' 출력 성공: 위도 35.050427010, 경도 128.964700408
# 인덱스 1, 주소 '동구 영초윗길 48(초량동), 장기려기념관 1층' 출력 성공: 위도 35.118525186, 경도 129.032654093
# 인덱스 2, 주소 '부산광역시 동구 충장대로289번길 17, 2층' 출력 성공: 위도 35.126976258, 경도 129.051826798
# 인덱스 3, 주소 '부산광역시 수영구 연수로275번길 30(망미동)' 출력 성공: 위도 35.174503670, 경도 129.101077058
# 인덱스 4, 주소 '부산시 사상구 백양대로 499 (주례동)' 출력 성공: 위도 35.153879982, 경도 128.997468943
# 인덱스 5, 주소 '부산시 사상구 엄궁남로 20 (엄궁동)' 출력 성공: 위도 35.125124757, 경도 128.970122018
# 인덱스 6, 주소 '부산시 연제구 중앙대로 1001(연산동) 부산시청 1층' 출력 성공: 위도 35.180460087, 경도 129.075610891
# 인덱스 7, 주소 '부산시 동래구 우장춘로 175(온천1동)' 출력 성공: 위도 35.221848653, 경도 129.075579428
# 인덱스 8, 주소 '부산광역시 강서구 명지오션시티10로 80' 출력 성공: 위도 35.086177215, 경도 128.904767676
# 인덱스 9, 주소 '중구 대청로 57-16' 출력 성공: 위도 35.103361791, 경도 129.026227081
# 인덱스 10, 주소 '서구 꽃마을로163번길 73(구덕문화공원 내)' 출력 성공: 위도 35.126405322, 경도 129.005272454
# 인덱스 11, 주소 '동구 자유평화로 30, 1층' 출력 성공: 위도 35.141090726, 경도 129.063423094
# 인덱스 12, 주소 '해운대구 수영강변대로 120 영화의전당 비프힐 1층' 출력 성공: 위도 35.170980017, 경도 129.127154504
# 인덱스 13, 주소 '영도구 함지로79번길 6, 영도도서관 1층 및 지하1층' 출력 성공: 위도 35.075572812, 경도 129.066494795
# 인덱스 14, 주소 '영도구 해양로 202(동삼동)' 출력 성공: 위도 35.088026200, 경도 129.071775599
# 인덱스 15, 주소 '영도구 꿈나무길 25(영선동1가), 영선1동행정복지센터 지하1층' 출력 성공: 위도 35.090242650, 경도 129.044715724
# 인덱스 16, 주소 '부산시 부산진구 서전로58번길 145(전포동), 전포어울더울복합문화센터 3층' 출력 성공: 위도 35.151329826, 경도 129.066481182
# 인덱스 17, 주소 '부산진구 전포대로190번길 35 (전포종합사회복지관)' 출력 성공: 위도 35.153665295, 경도 129.067535368
# 인덱스 18, 주소 '남구 황령대로319번가길 147' 출력 성공: 위도 35.152422726, 경도 129.088990076
# 인덱스 19, 주소 '북구 은행나무로 26(만덕동)' 출력 성공: 위도 35.207241325, 경도 129.037798094
# 인덱스 20, 주소 '부산광역시 북구 시랑로185번길 47' 출력 성공: 위도 35.197022875, 경도 129.015464553
# 인덱스 21, 주소 '북구 상학산복길215' 출력 성공: 위도 35.217161303, 경도 129.040213567
# 인덱스 22, 주소 '북구 금곡대로 324번길 29(화명동) 2층' 출력 성공: 위도 35.237255470, 경도 129.015762007
# 인덱스 23, 주소 '해운대구 해운대로 383번가길 7, 우2동 행정복지센터 2층' 출력 성공: 위도 35.171238301, 경도 129.139940045
# 인덱스 24, 주소 '사상구 덕상로72번길 9' 출력 성공: 위도 35.178113166, 경도 128.989813250
# 인덱스 25, 주소 '금정구 금정로 29-6, 1층(장전동, 세대공감센터)' 출력 성공: 위도 35.227474291, 경도 129.085511316
# 인덱스 26, 주소 '강서구 르노삼성대로 14(신호문화공원 본관 1층)' 출력 성공: 위도 35.088613859, 경도 128.872471999
# 인덱스 27, 주소 '강서구 공항로811번길 10(강서도서관 1층)' 출력 성공: 위도 35.180196450, 경도 128.957409772
# 인덱스 28, 주소 '연제구 연제로 2, 연제구청 1층' 출력 성공: 위도 35.176165590, 경도 129.079737441
# 인덱스 29, 주소 '연제구 해맞이로43번길 36(거제동) 2,3층' 출력 성공: 위도 35.179363353, 경도 129.066569015
# 인덱스 30, 주소 '연제구 안연로 8번길 71 연제구 아이사랑뜰' 출력 성공: 위도 35.188587228, 경도 129.104914322
# 인덱스 31, 주소 '정관중앙로 100 정관도서관 1층 어린이자료실' 출력 성공: 위도 35.325184674, 경도 129.181485266
# 인덱스 32, 주소 '사상구 낙동대로 1210번길 17' 출력 성공: 위도 35.168023089, 경도 128.977895348
# 인덱스 33, 주소 '금정구 체육공원로399번길 324(두구동)' 출력 성공: 위도 35.289017855, 경도 129.103842552
# 인덱스 34, 주소 '기장군 철마면 고촌로 51' 출력 성공: 위도 35.238729629, 경도 129.168697769
# 인덱스 35, 주소 '남구 백운포로 110(국민체육센터2관, 2층)' 출력 성공: 위도 35.103893413, 경도 129.108194423
# 인덱스 36, 주소 '동구 중앙대로 374' 출력 성공: 위도 35.128420809, 경도 129.049080440
# 인덱스 37, 주소 '동래구 낙민로 25, 사회복지종합센터 1층' 출력 성공: 위도 35.197781436, 경도 129.090764689
# 인덱스 38, 주소 '사상구 학감대로 242' 출력 성공: 위도 35.152648061, 경도 128.990916197
# 인덱스 39, 주소 '사하구 낙동남로1233번길 25' 출력 성공: 위도 35.110080577, 경도 128.944870220
# 인덱스 40, 주소 '동래구 아시아드대로231번길 21(온천동)' 출력 성공: 위도 35.204915032, 경도 129.066281622
# 인덱스 41, 주소 '동래구 금강로 129(온천동) 동래구혁신어울림센터' 출력 성공: 위도 35.220267293, 경도 129.080021626
# 인덱스 42, 주소 '북구 함박봉로 140번길 102, 만덕종합사회복지관 4층 들락날락' 출력 성공: 위도 35.201828250, 경도 129.035385346
# 인덱스 43, 주소 '사상구 백양대로 527(주례동), 사상구종합사회복지관 2층' 출력 성공: 위도 35.155434617, 경도 128.994770578
# 인덱스 44, 주소 '서구 까치고개로197번길 46, 서구문화원 1층' 출력 성공: 위도 35.102011405, 경도 129.017613859
# 인덱스 45, 주소 '연제구 고분로241번길 26(연산동) 2층' 출력 성공: 위도 35.185769123, 경도 129.108783183
# 인덱스 46, 주소 '중구 대청로 112(구. 한국은행), 부산근현대역사관 본관 중2층' 출력 성공: 위도 35.102366589, 경도 129.031780517
# 인덱스 47, 주소 '서구 해돋이로 297' 출력 성공: 위도 35.102785978, 경도 129.016174420
# 인덱스 48, 주소 '수영구 광안해변로295번길 20, 민락동행정복지센터 2층' 출력 성공: 위도 35.157222685, 경도 129.125446040
# 인덱스 71, 주소 '사하구 하신중앙로 185 사하구 제2청사 A동 5층' 출력 성공: 위도 35.094972723, 경도 128.961540674
# 인덱스 72, 주소 '사하구 을숙도대로745번길' 출력 성공: 위도 35.086371546, 경도 128.986043447
# 인덱스 73, 주소 '사하구 감내1로175번길 50' 출력 성공: 위도 35.096476886, 경도 129.009164557
# 인덱스 74, 주소 '사하구 다대로130번길 112' 출력 성공: 위도 35.093063130, 경도 128.975948470
# 인덱스 75, 주소 '사하구 장림로161번길 14, 2층' 출력 성공: 위도 35.083355200, 경도 128.967032810
# 인덱스 76, 주소 '부산진구 백양대로 227(3층)' 출력 성공: 위도 35.157309284, 경도 129.025810322
# 인덱스 77, 주소 '부산시 서구 아미동2가 249-18일원' 출력 실패. 재시도
# 인덱스 77, 주소 '부산시 서구 아미동2가 249-18일원' 재시도도 성공: 위도 35.10372936263688, 경도 129.00921520137797
# 인덱스 78, 주소 '부산광역시 서구 까치고개로 183' 출력 성공: 위도 35.100202209, 경도 129.015868464
# 인덱스 79, 주소 '부산광역시 중구 동영로 87-1, 영주터널 윗길(영주동)' 출력 성공: 위도 35.112721170, 경도 129.031627637
# 인덱스 80, 주소 '부산광역시 서구 송도해변로 100' 출력 성공: 위도 35.076820119, 경도 129.018049490
# 인덱스 81, 주소 '부산광역시 영도구 동삼오션로 27, 동삼2동 행정복지센터 2층' 출력 성공: 위도 35.068393845, 경도 129.083015770
# 인덱스 82, 주소 '부산광역시 영도구 영선대로 65, 영선2동 행정복지센터 3층' 출력 성공: 위도 35.086986860, 경도 129.041319763
# 인덱스 83, 주소 '부산광역시 부산진구 당감동 93-17 ' 출력 실패. 재시도
# 인덱스 83, 주소 '부산광역시 부산진구 당감동 93-17 ' 재시도도 성공: 위도 35.15766771118992, 경도 129.04689359288727
# 인덱스 84, 주소 '부산광역시 남구 수영로 267번길 61(대연동)' 출력 성공: 위도 35.137696705, 경도 129.094567839
# 인덱스 85, 주소 '부산광역시 해운대구 아랫반송로1번길 15(반송동)' 출력 성공: 위도 35.226408285, 경도 129.146907595
# 인덱스 86, 주소 '부산광역시 금정구 금강로 584, 4층(구서동)' 출력 성공: 위도 35.259554479, 경도 129.088035370
# 인덱스 87, 주소 '부산광역시 금정구 금정도서관로 33(청룡동)' 출력 성공: 위도 35.272718107, 경도 129.096198188
# 인덱스 88, 주소 '부산광역시 사상구 학장동 546번지 일원' 출력 실패. 재시도
# 인덱스 88, 주소 '부산광역시 사상구 학장동 546번지 일원' 재시도도 성공: 위도 35.142324347544346, 경도 128.98741453591447
# 인덱스 89, 주소 '부산광역시 사상구 냉정로 10(주례동) 주례3동 행정복지센터 2층' 출력 성공: 위도 35.147354849, 경도 129.001412225
# 인덱스 90, 주소 '부산광역시 사상구 모라동 1133번지 외 2필지' 출력 실패. 재시도
# 인덱스 90, 주소 '부산광역시 사상구 모라동 1133번지 외 2필지' 재시도도 성공: 위도 35.18915023986207, 경도 128.9861578442612
# 인덱스 91, 주소 '부산광역시 사하구 에덴공원 내 솔바람문화센터' 출력 실패. 재시도
# 인덱스 91, 주소 '부산광역시 사하구 에덴공원 내 솔바람문화센터' 출력 실패
# 인덱스 92, 주소 '부산광역시 영도구 동삼동 1158번지 부산복합혁신센터' 출력 실패. 재시도
# 인덱스 92, 주소 '부산광역시 영도구 동삼동 1158번지 부산복합혁신센터' 재시도도 성공: 위도 35.08049323350543, 경도 129.0766930075334
# 인덱스 93, 주소 '부산광역시 남구 대연동 1741-28, 캠코 신규직원사택 1층' 출력 실패. 재시도
# 인덱스 93, 주소 '부산광역시 남구 대연동 1741-28, 캠코 신규직원사택 1층' 재시도도 성공: 위도 35.13537081262156, 경도 129.09242727731748
# 인덱스 94, 주소 '부산광역시 사하구 장평로 270, 사하소방서 안전체험장' 출력 성공: 위도 35.090625519, 경도 128.973417430
# 인덱스 95, 주소 '부산광역시 동구 범일동 1400번지 좌성초등학교(폐교)' 출력 실패. 재시도
# 인덱스 95, 주소 '부산광역시 동구 범일동 1400번지 좌성초등학교(폐교)' 재시도도 성공: 위도 35.137401299549055, 경도 129.05212269279204
# 인덱스 96, 주소 '부산광역시 연제구 연산동 149-24 연제구 장애인 복지관 2층 어린이도서관' 출력 실패. 재시도
# 인덱스 96, 주소 '부산광역시 연제구 연산동 149-24 연제구 장애인 복지관 2층 어린이도서관' 재시도도 성공: 위도 35.18793017384141, 경도 129.11089239336042
# 인덱스 97, 주소 '부산광역시 수영구 황령산로7번길 60(옛 부산시장관사) 도모헌 들락날락 어린이도서관' 출력 성공: 위도 35.146321213, 경도 129.107180390
# 인덱스 98, 주소 '부산광역시 부산진구 초읍동 43번지 부산어린이대공원 관리사업소 ' 출력 실패. 재시도
# 인덱스 98, 주소 '부산광역시 부산진구 초읍동 43번지 부산어린이대공원 관리사업소 ' 재시도도 성공: 위도 35.185846766290766, 경도 129.04169078894188
# 인덱스 99, 주소 '부산광역시 영도구 해양로310번길 45 국립해양박물관내 어린이해양도서관' 출력 실패. 재시도
# 인덱스 99, 주소 '부산광역시 영도구 해양로310번길 45 국립해양박물관내 어린이해양도서관' 출력 실패
# 인덱스 100, 주소 '부산광역시 북구 덕천동 485-1번지' 출력 실패. 재시도
# 인덱스 100, 주소 '부산광역시 북구 덕천동 485-1번지' 재시도도 성공: 위도 35.2173088786191, 경도 129.0117297904718
# 인덱스 101, 주소 '부산광역시 동구 수정로 21' 출력 성공: 위도 35.128042957, 경도 129.044626485
# 인덱스 102, 주소 '부산광역시 사하구 승학로20번길 25' 출력 성공: 위도 35.106111868, 경도 128.972172557
# 인덱스 103, 주소 '부산광역시 기장군 일광읍 삼성리 197' 출력 실패. 재시도
# 인덱스 103, 주소 '부산광역시 기장군 일광읍 삼성리 197' 재시도도 성공: 위도 35.261594645573595, 경도 129.23070660906393
# 인덱스 104, 주소 '동래구 우장춘로 117' 출력 성공: 위도 35.217858768, 경도 129.074224891
# 인덱스 105, 주소 '부산진구 가야대로 734' 출력 성공: 위도 35.156745057, 경도 129.052320235
#    주소번호                이름                          주소            위도  \
# 0    27        다대도서관 들락날락            부산시 사하구 다대낙조2길 9  35.050427010
# 1    28  더나눔어린이작은도서관 들락날락  동구 영초윗길 48(초량동), 장기려기념관 1층  35.118525186
# 2    29   수남어린이작은도서관 들락날락   부산광역시 동구 충장대로289번길 17, 2층  35.126976258
# 3    30      망미작은도서관 들락날락  부산광역시 수영구 연수로275번길 30(망미동)  35.174503670
# 4    31      백양낙조전망대 들락날락      부산시 사상구 백양대로 499 (주례동)  35.153879982
#
#               경도
# 0  128.964700408
# 1  129.032654093
# 2  129.051826798
# 3  129.101077058
# 4  128.997468943

# %%
busan_df3 = pd.read_csv('부산광역시_좌표추가.csv') # 저장한 CSV 파일을 다시 읽어옴
busan_df3 # 수집된 데이터를 출력하여 누락되는 데이터 검토
# Out:
#      주소번호                       이름                          주소         위도  \
# 0      27               다대도서관 들락날락            부산시 사하구 다대낙조2길 9  35.050427
# 1      28         더나눔어린이작은도서관 들락날락  동구 영초윗길 48(초량동), 장기려기념관 1층  35.118525
# 2      29          수남어린이작은도서관 들락날락   부산광역시 동구 충장대로289번길 17, 2층  35.126976
# 3      30             망미작은도서관 들락날락  부산광역시 수영구 연수로275번길 30(망미동)  35.174504
# 4      31             백양낙조전망대 들락날락      부산시 사상구 백양대로 499 (주례동)  35.153880
# ..    ...                      ...                         ...        ...
# 101   232     동구어린이영어도서관 들락날락(조성중)             부산광역시 동구 수정로 21  35.128043
# 102   233        당리작은도서관 들락날락(조성중)        부산광역시 사하구 승학로20번길 25  35.106112
# 103   234          일광도서관 들락날락(조성중)       부산광역시 기장군 일광읍 삼성리 197  35.261595
# 104   235               부산119안전체험관                동래구 우장춘로 117  35.217859
# 105   236  부산글로벌빌리지 영어특화 들락날락(조성중)               부산진구 가야대로 734  35.156745
#
#              경도
# 0    128.964700
# 1    129.032654
# 2    129.051827
# 3    129.101077
# 4    128.997469
# ..          ...
# 101  129.044626
# 102  128.972173
# 103  129.230707
# 104  129.074225
# 105  129.052320
#
# [106 rows x 5 columns]

# %% [markdown]
# ### 106개 주소 중 3개 출력 실패 확인 후 별도 출력
# 1. 기장어린이도서관 들락날락: 기장군 기장읍 처성동로 126번길 13-5 -> 처성동로가 아닌 차성동로로 확인
# 2. 솔바람문화센터 들락날락(조성중): 부산광역시 사하구 에덴공원 내 솔바람문화센터는 검색해도 안 나옴. 구글 지도에서 에덴공원을 기점으로 좌표 검색 -> 네이버 지도에 다시 좌표 입력해서 일치하는지 확인
# 3. 국립해양박물관내 어린이해양도서관 들락날락(조성중): 부산광역시 영도구 해양로310번길 45 국립해양박물관내 어린이해양도서관
#     - 국립해양박물관은 해양로310번길이 아닌 해양로301번길로 확인.
#     - 들락날락 사이트 지도에 표시된 위치와 차이가 많이 남.

# %%
import pandas as pd
import requests

apikey = '' # API 키를 여기에 입력
pd.set_option('display.max_rows', None)
addr = '기장군 기장읍 차성동로 126번길 13-5'

import requests
apiurl = 'https://api.vworld.kr/req/address?'
params = {
	"service": "address",
	"request": "getcoord",
	"crs": "epsg:4326",
	"address": addr,
	"format": "json",
	"type": "road",
	"key": apikey,
}
response = requests.get(apiurl, params=params)
if response.status_code == 200:
	response_json = response.json()
response_json
point = response_json['response']['result']['point']
busan_df4.at[56, '위도'] = point['y']
busan_df4.at[56, '경도'] = point['x']
print(f"주소 '{addr}' 출력 성공: 위도 {point['y']}, 경도 {point['x']}")
# busan_df4.at[99, '주소'] = addr
busan_df4[['주소번호', '이름', '주소', '위도', '경도']]
# Out:
# 주소 '기장군 기장읍 차성동로 126번길 13-5' 출력 성공: 위도 35.249684877, 경도 129.217304190
#      주소번호                           이름  \
# 0      27                   다대도서관 들락날락
# 1      28             더나눔어린이작은도서관 들락날락
# 2      29              수남어린이작은도서관 들락날락
# 3      30                 망미작은도서관 들락날락
# 4      31                 백양낙조전망대 들락날락
# 5      32                   엄궁 통통 들락날락
# 6      33                    부산시청 들락날락
# 7      34              부산해양자연사박물관 들락날락
# 8      35                강서기적의도서관 들락날락
# 9      36           보수동책방골목어린이도서관 들락날락
# 10     37                서구 숲속놀이터 들락날락
# 11     38                애니랑Busan 들락날락
# 12     39                   영화의전당 들락날락
# 13     40                   영도도서관 들락날락
# 14     41              영도구 자원순환센터 들락날락
# 15     42               영선나릿작은도서관 들락날락
# 16     43             전포어울더울작은도서관 들락날락
# 17     44                꿈자람작은도서관 들락날락
# 18     45           대동골문화센터 작은도서관 들락날락
# 19     46                   만덕도서관 들락날락
# 20     47          시랑골 아이누리 작은도서관 들락날락
# 21     48                   상학도서관 들락날락
# 22     49                 솔밭작은도서관 들락날락
# 23     50            우2동 어린이작은도서관 들락날락
# 24     54                사상어린이도서관 들락날락
# 25     56          금정 아이꿈자람 작은도서관 들락날락
# 26     57                 신호작은도서관 들락날락
# 27     58                   강서도서관 들락날락
# 28     60                    연제구청 들락날락
# 29     61               해맞이 작은도서관 들락날락
# 30     62               연제구 아이사랑뜰 들락날락
# 31     63                   정관도서관 들락날락
# 32     64             사상구육아종합지원센터 들락날락
# 33     65                  금정체육공원 들락날락
# 34     66                고촌어울림도서관 들락날락
# 35     67            바다Dream작은도서관 들락날락
# 36     68       동구 시민마당 들락날락 어린이 작은도서관
# 37     71            부산사회복지종합센터 내 들락날락
# 38     73               사상구청 들락날락(조성중)
# 39     74                 을숙도문화회관 들락날락
# 40     75            온빛 어린이 작은도서관 들락날락
# 41     76            동래구혁신어울림센터 내 들락날락
# 42     77               만덕종합사회복지관 들락날락
# 43     79                꿈나래작은도서관 들락날락
# 44     80                천마니작은도서관 들락날락
# 45     81              토곡어린이작은도서관 들락날락
# 46     82         부산근현대역사관 어린이체험실 들락날락
# 47     83              한형석 자유아동극장 들락날락
# 48     84                 민락작은도서관 들락날락
# 49     85            송정동 어린이작은도서관 들락날락
# 50     86                   반여도서관 들락날락
# 51     87                학마을작은도서관 들락날락
# 52     88           부산진구어린이청소년도서관 들락날락
# 53     89  노을이 아름다운 하단복합센터(하단도서관) 들락날락
# 54     90                 수풀작은도서관 들락날락
# 55     91            연제만화도서관 들락날락(조성중)
# 56     92                기장어린이도서관 들락날락
# 57     95                 국회부산도서관 들락날락
# 58     96               부산도서관 꿈뜨락 들락날락
# 59     97                 밤골작은도서관 들락날락
# 60     98                 배산작은도서관 들락날락
# 61     99            회화나무어린이작은도서관 들락날락
# 62    101                 솔벗작은도서관 들락날락
# 63    108                     그리며 들락날락
# 64    181                    안데르센 이야기관
# 65    182             꽃마루어린이작은도서관 들락날락
# 66    183             부산진구 기적의도서관 들락날락
# 67    184              노을나루길작은도서관 들락날락
# 68    185                오작교작은도서관 들락날락
# 69    189         금정아이숲 들락날락 어린이복합문화공간
# 70    190               까치마을작은도서관 들락날락
# 71    191                꿈꾸는작은도서관 들락날락
# 72    192              구평예들 작은도서관 들락날락
# 73    193               감천횃불작은도서관 들락날락
# 74    194               동매누리작은도서관 들락날락
# 75    195              장림무지개작은도서관 들락날락
# 76    196                   한국신발관 들락날락
# 77    197          서구아미드림도서관 들락날락(조성중)
# 78    205                     아동보호종합센터
# 79    206          고맙습니다.글마루작은도서관(조성중)
# 80    207        백년송도 어린이해양역사 체험관(조성중)
# 81    208                    아랫서발작은도서관
# 82    209                 풀잎작은도서관(조성중)
# 83    210               부산진구당감도서관(조성중)
# 84    211                   남구도서관(조성중)
# 85    212               반송종합사회복지관(조성중)
# 86    213                 구서2동어린이작은도서관
# 87    214                   금정도서관(조성중)
# 88    215                학장동 신규청사(조성중)
# 89    216                 주례쌈지도서관(조성중)
# 90    217               모래내 다온플랫폼(조성중)
# 91    219            솔바람문화센터 들락날락(조성중)
# 92    222           부산복합혁신센터 들락날락(조성중)
# 93    223          캠코 신규직원사택 들락날락(조성중)
# 94    224        사하소방서 안전체험장 들락날락(조성중)
# 95    225             좌성초등학교 들락날락(조성중)
# 96    226   연제구장애인복지관 어린이도서관 들락날락(조성중)
# 97    227              도모헌 들락날락 어린이도서관
# 98    229      부산어린이해양복합문화공간 들락날락(조성중)
# 99    230  국립해양박물관내 어린이해양도서관 들락날락(조성중)
# 100   231              덕천도서관 들락날락(조성중)
# 101   232         동구어린이영어도서관 들락날락(조성중)
# 102   233            당리작은도서관 들락날락(조성중)
# 103   234              일광도서관 들락날락(조성중)
# 104   235                   부산119안전체험관
# 105   236      부산글로벌빌리지 영어특화 들락날락(조성중)
#
#                                                  주소            위도  \
# 0                                  부산시 사하구 다대낙조2길 9     35.050427
# 1                        동구 영초윗길 48(초량동), 장기려기념관 1층     35.118525
# 2                         부산광역시 동구 충장대로289번길 17, 2층     35.126976
# 3                        부산광역시 수영구 연수로275번길 30(망미동)     35.174504
# 4                            부산시 사상구 백양대로 499 (주례동)      35.15388
# 5                             부산시 사상구 엄궁남로 20 (엄궁동)     35.125125
# 6                    부산시 연제구 중앙대로 1001(연산동) 부산시청 1층      35.18046
# 7                            부산시 동래구 우장춘로 175(온천1동)     35.221849
# 8                            부산광역시 강서구 명지오션시티10로 80     35.086177
# 9                                      중구 대청로 57-16     35.103362
# 10                        서구 꽃마을로163번길 73(구덕문화공원 내)     35.126405
# 11                                  동구 자유평화로 30, 1층     35.141091
# 102                            부산광역시 사하구 승학로20번길 25     35.106112
# 103                           부산광역시 기장군 일광읍 삼성리 197     35.261595
# 104                                    동래구 우장춘로 117     35.217859
# 105                                   부산진구 가야대로 734     35.156745
#
#                 경도
# 0         128.9647
# 1       129.032654
# 2       129.051827
# 3       129.101077
# 4       128.997469
# 5       128.970122
# 6       129.075611
# 7       129.075579
# 8       128.904768
# 9       129.026227
# 10      129.005272
# 11      129.063423
# 12      129.127155
# 13      129.066495
# 14      129.071776
# 15      129.044716
# 16      129.066481
# 17      129.067535
# 18       129.08899
# 19      129.037798
# 20      129.015465
# 21      129.040214
# 22      129.015762
# 23       129.13994
# 24      128.989813
# 25      129.085511
# 26      128.872472
# 27       128.95741
# 28      129.079737
# 29      129.066569
# 30      129.104914
# 31      129.181485
# 32      128.977895
# 33      129.103843
# 34      129.168698
# 35      129.108194
# 36       129.04908
# 37      129.090765
# 38      128.990916
# 39       128.94487
# 40      129.066282
# 41      129.080022
# 42      129.035385
# 43      128.994771
# 44      129.017614
# 45      129.108783
# 46      129.031781
# 47      129.016174
# 48      129.125446
# 49       129.20372
# 50      129.133808
# 51      128.990004
# 52      129.039643
# 53      128.957606
# 54      128.978667
# 55      129.092894
# 56   129.217304190
# 57      128.904397
# 58      128.985289
# 59      129.094451
# 60      129.093325
# 61      128.991679
# 62       129.07013
# 63      128.985757
# 64      129.239892
# 65      129.011778
# 66      129.064702
# 67       128.96052
# 68      128.998079
# 69      129.054761
# 70      129.006345
# 71      128.961541
# 72      128.986043
# 73      129.009165
# 74      128.975948
# 75      128.967033
# 76       129.02581
# 77      129.009215
# 78      129.015868
# 79      129.031628
# 80      129.018049
# 81      129.083016
# 82       129.04132
# 83      129.046894
# 84      129.094568
# 85      129.146908
# 86      129.088035
# 87      129.096198
# 88      128.987415
# 89      129.001412
# 90      128.986158
# 91       128.96329
# 92      129.076693
# 93      129.092427
# 94      128.973417
# 95      129.052123
# 96      129.110892
# 97       129.10718
# 98      129.041691
# 99   129.080199790
# 100      129.01173
# 101     129.044626
# 102     128.972173
# 103     129.230707
# 104     129.074225
# 105      129.05232

# %%
busan_df4.to_csv('부산광역시_좌표추가_수정.csv', index=False, encoding='utf-8')
busan_df5 = pd.read_csv('부산광역시_좌표추가_수정.csv')
busan_df5
# Out:
#      주소번호                           이름  \
# 0      27                   다대도서관 들락날락
# 1      28             더나눔어린이작은도서관 들락날락
# 2      29              수남어린이작은도서관 들락날락
# 3      30                 망미작은도서관 들락날락
# 4      31                 백양낙조전망대 들락날락
# 5      32                   엄궁 통통 들락날락
# 6      33                    부산시청 들락날락
# 7      34              부산해양자연사박물관 들락날락
# 8      35                강서기적의도서관 들락날락
# 9      36           보수동책방골목어린이도서관 들락날락
# 10     37                서구 숲속놀이터 들락날락
# 11     38                애니랑Busan 들락날락
# 12     39                   영화의전당 들락날락
# 13     40                   영도도서관 들락날락
# 14     41              영도구 자원순환센터 들락날락
# 15     42               영선나릿작은도서관 들락날락
# 16     43             전포어울더울작은도서관 들락날락
